# %% [markdown]
# Igor Lucas dos Santos Braz - 3865

# %% [markdown]
# ## Questão 1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/usuarios_cartao_credito-prova (1).csv')
df
# Out:
#        Id_Cliente   Indicador_Status  Idade Sexo  n_dependentes  \
# 0       768805383  Existing Customer     45    M              3
# 1       818770008  Existing Customer     49    F              5
# 2       713982108  Existing Customer     51    M              3
# 3       769911858  Existing Customer     40    F              4
# 4       709106358  Existing Customer     40    M              3
# ...           ...                ...    ...  ...            ...
# 10122   772366833  Existing Customer     50    M              2
# 10123   710638233  Attrited Customer     41    M              2
# 10124   716506083  Attrited Customer     44    F              1
# 10125   717406983  Attrited Customer     30    M              2
# 10126   714337233  Attrited Customer     43    F              2
#
#       nivel_educacao estado_civil           renda categoria_cartao  \
# 0        High School      Married     $60K - $80K             Blue
# ...

# %%
df['Sexo'] = df['Sexo'].apply(lambda x: 1 if x == 'F' else 0)
df
# Out:
#        Id_Cliente   Indicador_Status  Idade  Sexo  n_dependentes  \
# 0       768805383  Existing Customer     45     0              3
# 1       818770008  Existing Customer     49     1              5
# 2       713982108  Existing Customer     51     0              3
# 3       769911858  Existing Customer     40     1              4
# 4       709106358  Existing Customer     40     0              3
# ...           ...                ...    ...   ...            ...
# 10122   772366833  Existing Customer     50     0              2
# 10123   710638233  Attrited Customer     41     0              2
# 10124   716506083  Attrited Customer     44     1              1
# 10125   717406983  Attrited Customer     30     0              2
# 10126   714337233  Attrited Customer     43     1              2
#
#       nivel_educacao estado_civil           renda categoria_cartao  \
# 0        High School      Married     $60K - $80K             Blue
# ...

# %%
df['renda'] = df["renda"].astype('category')
df['renda'] = df['renda'].cat.codes
df
# Out:
#        Id_Cliente   Indicador_Status  Idade  Sexo  n_dependentes  \
# 0       768805383  Existing Customer     45     0              3
# 1       818770008  Existing Customer     49     1              5
# 2       713982108  Existing Customer     51     0              3
# 3       769911858  Existing Customer     40     1              4
# 4       709106358  Existing Customer     40     0              3
# ...           ...                ...    ...   ...            ...
# 10122   772366833  Existing Customer     50     0              2
# 10123   710638233  Attrited Customer     41     0              2
# 10124   716506083  Attrited Customer     44     1              1
# 10125   717406983  Attrited Customer     30     0              2
# 10126   714337233  Attrited Customer     43     1              2
#
#       nivel_educacao estado_civil  renda categoria_cartao  meses_contrato  \
# 0        High School      Married      2             Blue              39
# ...

# %%
df['nivel_educacao'] = df["nivel_educacao"].astype('category')
df['nivel_educacao'] = df['nivel_educacao'].cat.codes
df
# Out:
#        Id_Cliente   Indicador_Status  Idade  Sexo  n_dependentes  \
# 0       768805383  Existing Customer     45     0              3
# 1       818770008  Existing Customer     49     1              5
# 2       713982108  Existing Customer     51     0              3
# 3       769911858  Existing Customer     40     1              4
# 4       709106358  Existing Customer     40     0              3
# ...           ...                ...    ...   ...            ...
# 10122   772366833  Existing Customer     50     0              2
# 10123   710638233  Attrited Customer     41     0              2
# 10124   716506083  Attrited Customer     44     1              1
# 10125   717406983  Attrited Customer     30     0              2
# 10126   714337233  Attrited Customer     43     1              2
#
#        nivel_educacao estado_civil  renda categoria_cartao  meses_contrato  \
# 0                   3      Married      2             Blue              39
# ...

# %%
df['categoria_cartao'] = df["categoria_cartao"].astype('category')
df['categoria_cartao'] = df['categoria_cartao'].cat.codes

# %%
df['categoria_cartao'].unique()
# Out:
# array([0, 1, 3, 2], dtype=int8)

# %%
#df = pd.get_dummies(df, columns=["categoria_cartao"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id_Cliente        10127 non-null  int64
#  1   Indicador_Status  10127 non-null  object
#  2   Idade             10127 non-null  int64
#  3   Sexo              10127 non-null  int64
#  4   n_dependentes     10127 non-null  int64
#  5   nivel_educacao    10127 non-null  int8
#  6   estado_civil      10127 non-null  object
#  7   renda             10127 non-null  int8
#  8   categoria_cartao  10127 non-null  int8
#  9   meses_contrato    10127 non-null  int64
#  10  n_produtos        10127 non-null  int64
#  11  limite_credito    10127 non-null  float64
#  12  total_transacoes  10127 non-null  int64
# dtypes: float64(1), int64(7), int8(3), object(2)
# memory usage: 821.0+ KB

# %%
df.columns
# Out:
# Index(['Id_Cliente', 'Indicador_Status', 'Idade', 'Sexo', 'n_dependentes',
#        'nivel_educacao', 'estado_civil', 'renda', 'categoria_cartao',
#        'meses_contrato', 'n_produtos', 'limite_credito', 'total_transacoes'],
#       dtype='object')

# %%
coluna_interesse = ['Idade', 'Sexo','nivel_educacao','renda','meses_contrato', 
                    'total_transacoes', 'categoria_cartao']
target = 'limite_credito'

# %%
cols_interesse_all = coluna_interesse.copy()
cols_interesse_all.append(target)
df[cols_interesse_all]
# Out:
#        Idade  Sexo  nivel_educacao  renda  meses_contrato  total_transacoes  \
# 0         45     0               3      2              39                42
# 1         49     1               2      4              44                33
# 2         51     0               2      3              36                20
# 3         40     1               3      4              34                20
# 4         40     0               5      2              21                28
# ...      ...   ...             ...    ...             ...               ...
# 10122     50     0               2      1              40               117
# 10123     41     0               6      1              25                69
# 10124     44     1               3      4              36                60
# 10125     30     0               2      1              36                62
# 10126     43     1               2      4              25                61
#
#        categoria_cartao  limite_credito
# ...

# %%
#sns.pairplot(df[cols_interesse_all])

# %%
Var_Corr = df[cols_interesse_all].corr()
matrix = np.triu(df[cols_interesse_all].corr())

plt.figure(figsize = (20,7))
sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns,\
            annot=True,center= 0, cmap= 'coolwarm',mask=matrix)

# %% [markdown]
# Na imagem a acima, podemos avaliar qual as colunas possuem maior relação.

# %% [markdown]
# Fazendo a Regrassão linear:

# %%
from sklearn.linear_model import LinearRegression

def regressao_linear(X,Y,cols):

  if len(cols) == 1:
    X = X.values.reshape(-1,1)

  lm = LinearRegression()
  lm.fit(X,Y)
  print('Coeficiente estimado: ', lm.coef_)    
  print('R2 (score): ', lm.score(X,Y))
  print("Intercept %.3f " % lm.intercept_)

  coeff_df = pd.DataFrame(lm.coef_, cols, columns=['Coefficient'])
  print(coeff_df)

Y = df[target]
Y
# Out:
# 0        12691.0
# 1         8256.0
# 2         3418.0
# 3         3313.0
# 4         4716.0
#           ...
# 10122     4003.0
# 10123     4277.0
# 10124     5409.0
# 10125     5281.0
# 10126    10388.0
# Name: limite_credito, Length: 10127, dtype: float64

# %% [markdown]
# abaixo, temos uma precisão maior das relações

# %%
df_corr = df.corr('kendall')
df_corr
# Out:
#                   Id_Cliente     Idade      Sexo  n_dependentes  \
# Id_Cliente          1.000000  0.011807 -0.016547      -0.002890
# Idade               0.011807  1.000000  0.014502      -0.109732
# Sexo               -0.016547  0.014502  1.000000      -0.004367
# n_dependentes      -0.002890 -0.109732 -0.004367       1.000000
# nivel_educacao     -0.003587  0.002390 -0.003626       0.000698
# renda              -0.020137 -0.007286  0.524692      -0.029374
# categoria_cartao    0.000339 -0.018508 -0.084484       0.025441
# meses_contrato      0.074625  0.613382  0.007912      -0.088070
# n_produtos          0.009944 -0.010539 -0.002639      -0.028358
# limite_credito      0.009513  0.001835 -0.362003       0.037302
# total_transacoes    0.004475 -0.035966  0.072107       0.038785
#
#                   nivel_educacao     renda  categoria_cartao  meses_contrato  \
# Id_Cliente             -0.003587 -0.020137          0.000339        0.074625
# ...

# %% [markdown]
# Com isso vemos que as melhores variaveis para relacionar com o limite é, Sexo, Categoria e renda

# %%
X = df['Sexo']
regressao_linear(X,Y,['Sexo'])
# Out:
# Coeficiente estimado:  [-7661.82068932]
# R2 (score):  0.17707791685760688
# Intercept 12685.675
#       Coefficient
# Sexo -7661.820689

# %%
X = df['categoria_cartao']
regressao_linear(X,Y,['categoria_cartao'])
# Out:
# Coeficiente estimado:  [6348.53512593]
# R2 (score):  0.2343430357416556
# Intercept 7490.383
#                   Coefficient
# categoria_cartao  6348.535126

# %%
X = df['renda']
regressao_linear(X,Y,['renda'])
# Out:
# Coeficiente estimado:  [-1361.43911702]
# R2 (score):  0.05080252402821972
# Intercept 12531.017
#        Coefficient
# renda -1361.439117

# %%
from sklearn.linear_model import LinearRegression
X = df[['Sexo','categoria_cartao','renda']]
Y = df['limite_credito']
lm = LinearRegression()
lm.fit(X,Y)
print('R2 (score): ', lm.score(X.values,Y))
# Out:
# R2 (score):  0.3815925852304475
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
print("Intercept %.3f " % lm.intercept_)

coeff_df = pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
# Intercept 11171.356
#                   Coefficient
# Sexo             -7087.425763
# categoria_cartao  5949.713860
# renda               49.080291

# %% [markdown]
# Agora utilizando a variavel nivel_educacao, temos:

# %%
from sklearn.linear_model import LinearRegression
X = df[['Sexo','categoria_cartao','renda', 'nivel_educacao']]
Y = df['limite_credito']
lm = LinearRegression()
lm.fit(X,Y)
print('R2 (score): ', lm.score(X.values,Y))
# Out:
# R2 (score):  0.3816305706960612
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
print("Intercept %.3f " % lm.intercept_)

coeff_df = pd.DataFrame(lm.coef_, X.columns, columns=['Coefficient'])
coeff_df
# Out:
# Intercept 11075.558
#                   Coefficient
# Sexo             -7088.147800
# categoria_cartao  5950.315312
# renda               49.612649
# nivel_educacao      30.532726

# %% [markdown]
# Com isso, podemos perceber que as melhores combinações para a previsão é:
#
#
# *   Sexo
# *   categoria do cartão
# *   Rende
# *   Nivel de Educação.

# %% [markdown]
# ## Questão 2

# %%
var = ['Sexo', 'renda','nivel_educacao', 'limite_credito']
target = df['categoria_cartao']

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn import cluster

# %%
kmeans = cluster.KMeans(n_clusters=2).fit(df[var])

# %% [markdown]
# Analisando o kmeans sempre utilizando o limite de credito como X.

# %%
def plot_cluster(model, df, attr_x, attr_y):
  plt.figure(figsize=(10,3))
  sns.scatterplot(x=df[attr_x], y=df[attr_y], hue=model.labels_, s=40)
  plt.title('Classificação K-Means') 
    
  plt.show()

# %%
X = df['limite_credito']

# %%
plt.subplot(1,2,1)
sns.scatterplot(x=df['limite_credito'], y=df['Sexo'], hue=target, s=40)
plt.title('Classificação Real')

plt.subplot(1,2,2)
sns.scatterplot(x=df['limite_credito'], y=df['Sexo'], hue=kmeans.labels_, s=40)
plt.title('Classificação K-Means') 

plt.show()

# %%
plt.subplot(1,2,1)
sns.scatterplot(x=df['limite_credito'], y=df['renda'], hue=target, s=40)
plt.title('Classificação Real')

plt.subplot(1,2,2)
sns.scatterplot(x=df['limite_credito'], y=df['renda'], hue=kmeans.labels_, s=40)
plt.title('Classificação K-Means') 

plt.show()

# %%
plt.subplot(1,2,1)
sns.scatterplot(x=df['limite_credito'], y=df['nivel_educacao'], hue=target, s=40)
plt.title('Classificação Real')

plt.subplot(1,2,2)
sns.scatterplot(x=df['limite_credito'], y=df['nivel_educacao'], hue=kmeans.labels_, s=40)
plt.title('Classificação K-Means') 

plt.show()

# %% [markdown]
# Agora vendo a silhueta entre eles:

# %%
from sklearn import metrics

# %%
print('Silhueta:', round(metrics.silhouette_score(df[var], kmeans.labels_), 4))
# Out:
# Silhueta: 0.7595

# %% [markdown]
# Com isso, percebe-se que os valores da nossa analise está 0,7595 com valores longes do outro cluster
