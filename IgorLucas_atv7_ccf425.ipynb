# %% [markdown]
# > Introdução à Ciência dos Dados \
# > Ciência da Computação – UFV/Florestal
#
#
# * **Nome:** Igor Lucas dos Santos Braz
# * **Matrícula:**  3865
#
# # Aula Prática 07
# ## Regras de Associação e o Algoritmo Apriori
#
# **Objetivo:** Aplicar o algoritmo Apriori para extrair regras de associação de dados reais.
# **Pré-requisitos:** Linguagem de programação Python, estatística básica \
# **Meta:** Ao final da prática, o aluno será capaz de preparar dados e extrair regras de associação desses dados utilizado o algoritmo Apriori.
#
# ----

# %%
### NÃO REMOVA ESSA CÉLULA! ####
# !pip --no-cache-dir install --upgrade learntools_dados_ufv

# !wget https://raw.githubusercontent.com/gfviegas/CCF425-resources/master/p6/OnlineRetail.xlsx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting learntools_dados_ufv
#   Downloading learntools_dados_ufv-1.0.7.tar.gz (27 kB)
# Building wheels for collected packages: learntools-dados-ufv
#   Building wheel for learntools-dados-ufv (setup.py) ... done
#   Created wheel for learntools-dados-ufv: filename=learntools_dados_ufv-1.0.7-py3-none-any.whl size=34186 sha256=55a8508d79d711f9b631ddb282dec4d018f6ac4cc82e598865d2c099d6c60822
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g_pw2mle/wheels/73/57/b7/2917e30fd3c237c7f74ef18c402800884a195fc7da27c7ffaa
# Successfully built learntools-dados-ufv
# Installing collected packages: learntools-dados-ufv
# Successfully installed learntools-dados-ufv-1.0.7
# --2022-07-01 19:25:06--  https://raw.githubusercontent.com/gfviegas/CCF425-resources/master/p6/OnlineRetail.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23715344 (23M) [application/octet-stream]
# Saving to: ‘OnlineRetail.xlsx’
#
# OnlineRetail.xlsx   100%[===================>]  22.62M  --.-KB/s    in 0.08s
#
# 2022-07-01 19:25:06 (285 MB/s) - ‘OnlineRetail.xlsx’ saved [23715344/23715344]

# %%
#### Não altere essa célula!!! ####
import pandas as pd
import string
import random

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

from learntools_dados_ufv.core import binder; binder.bind(globals())
from learntools_dados_ufv.ccf425.pratica_7 import *

# %% [markdown]
# # Roteiro

# %% [markdown]
# ## Estruturando os dados

# %% [markdown]
# ### Criar o conjunto de dados

# %%
dataset = [['Leite', 'Cebola', 'Nutela', 'Feijão', 'Ovo', 'Iogurte'],
          ['Arroz', 'Cebola', 'Nutela', 'Feijão', 'Ovo', 'Iogurte'],
          ['Leite', 'Maça', 'Feijão', 'Ovo'],
          ['Leite', 'Chocolate', 'Pipoca', 'Feijão', 'Iogurte'],
          ['Pipoca', 'Cebola', 'Feijão', 'Sorvete', 'Ovo']]

dataset
# Out:
# [['Leite', 'Cebola', 'Nutela', 'Feijão', 'Ovo', 'Iogurte'],
#  ['Arroz', 'Cebola', 'Nutela', 'Feijão', 'Ovo', 'Iogurte'],
#  ['Leite', 'Maça', 'Feijão', 'Ovo'],
#  ['Leite', 'Chocolate', 'Pipoca', 'Feijão', 'Iogurte'],
#  ['Pipoca', 'Cebola', 'Feijão', 'Sorvete', 'Ovo']]

# %% [markdown]
# ### Transformar no formato para ser utilizado no Apriori

# %%
transactions_oht = TransactionEncoder()
transactions = transactions_oht.fit(dataset).transform(dataset)
transactions
# Out:
# array([[False,  True, False,  True,  True,  True, False,  True,  True,
#         False, False],
#        [ True,  True, False,  True,  True, False, False,  True,  True,
#         False, False],
#        [False, False, False,  True, False,  True,  True, False,  True,
#         False, False],
#        [False, False,  True,  True,  True,  True, False, False, False,
#          True, False],
#        [False,  True, False,  True, False, False, False, False,  True,
#          True,  True]])

# %%
df = pd.DataFrame(transactions, columns=transactions_oht.columns_)
df
# Out:
#    Arroz  Cebola  Chocolate  Feijão  Iogurte  Leite   Maça  Nutela    Ovo  \
# 0  False    True      False    True     True   True  False    True   True
# 1   True    True      False    True     True  False  False    True   True
# 2  False   False      False    True    False   True   True   False   True
# 3  False   False       True    True     True   True  False   False  False
# 4  False    True      False    True    False  False  False   False   True
#
#    Pipoca  Sorvete
# 0   False    False
# 1   False    False
# 2   False    False
# 3    True    False
# 4    True     True

# %% [markdown]
# ## Calcular conjunto de itens frequentes
#
# Com suporte mínimo de 0.6

# %%
# Calcula os conjuntos de itens frequentes, com suporte minimo de 0.6
frequent_itemsets = apriori(df, min_support=0.6, use_colnames=True)
frequent_itemsets
# Out:
#     support               itemsets
# 0       0.6               (Cebola)
# 1       1.0               (Feijão)
# 2       0.6              (Iogurte)
# 3       0.6                (Leite)
# 4       0.8                  (Ovo)
# 5       0.6       (Cebola, Feijão)
# 6       0.6          (Cebola, Ovo)
# 7       0.6      (Feijão, Iogurte)
# 8       0.6        (Feijão, Leite)
# 9       0.8          (Ovo, Feijão)
# 10      0.6  (Cebola, Ovo, Feijão)

# %% [markdown]
# ## Calcular regras de associacão utilizando o Apriori
#
# Com filtro de confiança de 0.1

# %%
rules = association_rules(frequent_itemsets, metric='confidence', min_threshold=0.1)
rules
# Out:
#          antecedents       consequents  antecedent support  \
# 0           (Cebola)          (Feijão)                 0.6
# 1           (Feijão)          (Cebola)                 1.0
# 2           (Cebola)             (Ovo)                 0.6
# 3              (Ovo)          (Cebola)                 0.8
# 4           (Feijão)         (Iogurte)                 1.0
# 5          (Iogurte)          (Feijão)                 0.6
# 6           (Feijão)           (Leite)                 1.0
# 7            (Leite)          (Feijão)                 0.6
# 8              (Ovo)          (Feijão)                 0.8
# 9           (Feijão)             (Ovo)                 1.0
# 10     (Cebola, Ovo)          (Feijão)                 0.6
# 11  (Cebola, Feijão)             (Ovo)                 0.6
# 12     (Ovo, Feijão)          (Cebola)                 0.8
# 13          (Cebola)     (Ovo, Feijão)                 0.6
# 14             (Ovo)  (Cebola, Feijão)                 0.8
# 15          (Feijão)     (Cebola, Ovo)                 1.0
#
#     consequent support  support  confidence  lift  leverage  conviction
# 0                  1.0      0.6        1.00  1.00      0.00         inf
# 1                  0.6      0.6        0.60  1.00      0.00         1.0
# 2                  0.8      0.6        1.00  1.25      0.12         inf
# 3                  0.6      0.6        0.75  1.25      0.12         1.6
# 4                  0.6      0.6        0.60  1.00      0.00         1.0
# 5                  1.0      0.6        1.00  1.00      0.00         inf
# 6                  0.6      0.6        0.60  1.00      0.00         1.0
# 7                  1.0      0.6        1.00  1.00      0.00         inf
# 8                  1.0      0.8        1.00  1.00      0.00         inf
# 9                  0.8      0.8        0.80  1.00      0.00         1.0
# 10                 1.0      0.6        1.00  1.00      0.00         inf
# 11                 0.8      0.6        1.00  1.25      0.12         inf
# 12                 0.6      0.6        0.75  1.25      0.12         1.6
# 13                 0.8      0.6        1.00  1.25      0.12         inf
# 14                 0.6      0.6        0.75  1.25      0.12         1.6
# 15                 0.6      0.6        0.60  1.00      0.00         1.0

# %%
# Filtro por 'confidence'. Pode ser feito por outros campos também
rules[rules['confidence'] > 0.75]
# Out:
#          antecedents    consequents  antecedent support  consequent support  \
# 0           (Cebola)       (Feijão)                 0.6                 1.0
# 2           (Cebola)          (Ovo)                 0.6                 0.8
# 5          (Iogurte)       (Feijão)                 0.6                 1.0
# 7            (Leite)       (Feijão)                 0.6                 1.0
# 8              (Ovo)       (Feijão)                 0.8                 1.0
# 9           (Feijão)          (Ovo)                 1.0                 0.8
# 10     (Cebola, Ovo)       (Feijão)                 0.6                 1.0
# 11  (Cebola, Feijão)          (Ovo)                 0.6                 0.8
# 13          (Cebola)  (Ovo, Feijão)                 0.6                 0.8
#
#     support  confidence  lift  leverage  conviction
# 0       0.6         1.0  1.00      0.00         inf
# 2       0.6         1.0  1.25      0.12         inf
# 5       0.6         1.0  1.00      0.00         inf
# 7       0.6         1.0  1.00      0.00         inf
# 8       0.8         1.0  1.00      0.00         inf
# 9       0.8         0.8  1.00      0.00         1.0
# 10      0.6         1.0  1.00      0.00         inf
# 11      0.6         1.0  1.25      0.12         inf
# 13      0.6         1.0  1.25      0.12         inf

# %% [markdown]
# # Exercícios
#
# Os exercícios abaixo são referentes ao conjunto de dados `OnlineRetail` que já foi utilizado em práticas anteriores

# %% [markdown]
# Execute e não remova a célula abaixo antes de iniciar os exercícios. Faça todas as atividades manipulando a variável `df`.

# %%
# Atribui o dataframe com o estado "original" em uma variável isolada
original_df = pd.read_excel('./OnlineRetail.xlsx')
df = original_df.copy()
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# ## 1. Faça uma preparação dos dados.
# Antes de fazer a análise de regras de associação, é necessário que você trate alguns dados desse dataset. Essa prática é **extramemente** importante e comum, já que os dados que encntramos ~~quase nunca~~ nem sempre estão prontos para serem manipulados.

# %% [markdown]
# ### 1.a. Remova os espaços em branco do começo e fim da coluna de Descrição do Produto
# Faça a alteração do dataframe reatribuindo a variável `df`.
# > Não use o argumento `inplace=True`
#
# Chame a função `q1.a.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q1.a.hint()`

# %%
# Resposta da 1.a

q1.a.hint(3)

df['Description'] = df['Description'].str.strip()
df
q1.a.check()
# Out:
# Dica 3: Altere uma coluna usando a sintaxe `df.Coluna = df.Coluna.algumacoisa()`.
# CORRETO:

# %% [markdown]
# ### 1.b. Remova as instâncias que não possuem um Número de Nota Fiscal
# Faça a alteração do dataframe reatribuindo a variável `df`.
# > Não use o argumento `inplace=True`
#
# Chame a função `q1.b.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q1.b.hint()`

# %%
# Resposta da 1.b

q1.b.hint(2)

df = df.dropna(subset = ['InvoiceNo']) 

q1.b.check()
# Out:
# Dica 2: Pesquise sobre os parâmetros `subset` e `axis` da função `dropna`.
# (Para outra dica, chame `.hint(3)`)
# CORRETO:

# %% [markdown]
# ### 1.c. Converta a coluna de Número de Nota Fiscal para string
# Faça a alteração do dataframe reatribuindo a variável `df`.
# > Não use o argumento `inplace=True`
#
# Chame a função `q1.c.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q1.c.hint()`

# %%
# Resposta da 1.c

# q1.c.hint()

df['InvoiceNo'] = df['InvoiceNo'].astype(str) 

q1.c.check()
# Out:
# CORRETO:

# %% [markdown]
# ## 2. Faça a recuperação e formatação de transações relevantes.
# Vamos analisar somente as compras realizadas no país **Alemanha (Germany)**

# %% [markdown]
# ### 2.a. Filtre o dataframe para recupearar somente as compras realizadas no país `Germany`
# Armazene-a na variável `df_germany`.
#
# Chame a função `q2.a.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q2.a.hint()`

# %%
# Resposta da 2.a

# q2.a.hint()

df_germany = df[df['Country'] == 'Germany']
df_germany
q2.a.check()
# Out:
# CORRETO:

# %% [markdown]
# ### 2.b. A partir do `df_germany`, recupere um dataframe agrupado pelo Número da Nota Fiscal e Descrição do Produto
#
# Armazene-a na variável `df_germany_grouped`.
#
# Chame a função `q2.b.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q2.b.hint()`

# %%
# Resposta da 2.b

q2.b.hint(2)

df_germany_grouped = df_germany.groupby(by=['InvoiceNo', 'Description'])
df_germany_grouped

q2.b.check()
df_germany_grouped
# Out:
# Dica 2: Você pode passar uma lista para a função `groupby`.
# (Para outra dica, chame `.hint(3)`)
# CORRETO:

# %% [markdown]
# ### 2.c. A partir de `df_germany_grouped`, recupere a **Soma da Quantidade** de cada produto
#
# Armazene-a na variável `df_germany_grouped_sum`.
#
# Chame a função `q2.c.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q2.c.hint()`

# %%
# Resposta da 2.c

# q2.c.hint()

df_germany_grouped_sum = df_germany_grouped['Quantity'].sum()

q2.c.check()
df_germany_grouped_sum
# Out:
# CORRETO:
# InvoiceNo  Description
# 536527     3 HOOK HANGER MAGIC GARDEN             12
#            5 HOOK HANGER MAGIC TOADSTOOL          12
#            5 HOOK HANGER RED MAGIC TOADSTOOL      12
#            ASSORTED COLOUR LIZARD SUCTION HOOK    24
#            CHILDREN'S CIRCUS PARADE MUG           12
#                                                   ..
# C581409    SMALL SQUARE CUT GLASS CANDLESTICK     -5
#            STORAGE TIN HOME SWEET HOME            -3
#            VINTAGE LEAF CHOPPING BOARD            -1
#            WOOD BLACK BOARD ANT WHITE FINISH      -1
#            WOODEN PICTURE FRAME WHITE FINISH      -1
# Name: Quantity, Length: 9466, dtype: int64

# %% [markdown]
# ### 2.d. A partir de `df_germany_grouped_sum`, recupere um dataframe onde cada coluna possui a **soma da quantidade de cada produto**
# Armazene-a na variável `df_germany_basket`.
#
# #### Atenção:
# - O dataframe deve possuir **uma coluna para cada descrição de produto**.
# - Atribua o índice do dataframe com o **Número da Nota Fiscal**.
# - Todos os valores `NaN` devem ser convertidos para `0`
#
#
# Chame a função `q2.d.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q2.d.hint()`

# %%
# Resposta da 2.d

q2.d.hint(1)
q2.d.hint(2)
q2.d.hint(3)
q2.d.hint(4)
q2.d.hint(5)



df_germany_basket = df_germany_grouped_sum.unstack()
df_germany_basket = df_germany_basket.reset_index()
df_germany_basket = df_germany_basket.fillna(0)
df_germany_basket = df_germany_basket.set_index('InvoiceNo')
q2.d.check()
df_germany_basket
# Out:
# Dica 1: Pesquise sobre a função `unstack` do Pandas.
# (Para outra dica, chame `.hint(2)`)
# Dica 2: Pesquise sobre a função `reset_index` do Pandas.
# (Para outra dica, chame `.hint(3)`)
# Dica 3: Pesquise sobre a função `fillna` do Pandas.
# (Para outra dica, chame `.hint(4)`)
# Dica 4: Pesquise sobre a função `set_index` do Pandas.
# (Para outra dica, chame `.hint(5)`)
# Dica 5: Utilize as dicas anteriores em sequência.
# CORRETO:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                          0.0                         0.0
# 536840                          0.0                         0.0
# 536861                          0.0                         0.0
# 536967                          0.0                         0.0
# 536983                          0.0                         0.0
# ...                             ...                         ...
# C580313                         0.0                         0.0
# C580714                         0.0                         0.0
# C580740                         0.0                         0.0
# C580989                         0.0                         0.0
# C581409                         0.0                         0.0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
# ...                                       ...
# C580313                                   0.0
# C580714                                   0.0
# C580740                                   0.0
# C580989                                   0.0
# C581409                                   0.0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                   0.0                            0.0
# 536840                                   0.0                            0.0
# 536861                                   0.0                            0.0
# 536967                                   0.0                            0.0
# 536983                                   0.0                            0.0
# ...                                      ...                            ...
# C580313                                  0.0                            0.0
# C580714                                  0.0                            0.0
# C580740                                  0.0                            0.0
# C580989                                  0.0                            0.0
# C581409                                  0.0                            0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                       0.0                          0.0
# 536840                                       0.0                          0.0
# 536861                                       0.0                          0.0
# 536967                                       0.0                          0.0
# 536983                                       0.0                          0.0
# ...                                          ...                          ...
# C580313                                      0.0                          0.0
# C580714                                      0.0                          0.0
# C580740                                      0.0                          0.0
# C580989                                      0.0                          0.0
# C581409                                      0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                             0.0                                 0.0
# 536840                             0.0                                 0.0
# 536861                             0.0                                 0.0
# 536967                             0.0                                 0.0
# 536983                             0.0                                 0.0
# ...                                ...                                 ...
# C580313                            0.0                                 0.0
# C580714                            0.0                                 0.0
# C580740                            0.0                                 0.0
# C580989                            0.0                                 0.0
# C581409                            0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE SKULLS  ...  YULETIDE IMAGES GIFT WRAP SET  \
# InvoiceNo                                 ...
# 536527                               0.0  ...                            0.0
# 536840                               0.0  ...                            0.0
# 536861                               0.0  ...                            0.0
# 536967                               0.0  ...                            0.0
# 536983                               0.0  ...                            0.0
# ...                                  ...  ...                            ...
# C580313                              0.0  ...                            0.0
# C580714                              0.0  ...                            0.0
# C580740                              0.0  ...                            0.0
# C580989                              0.0  ...                            0.0
# C581409                              0.0  ...                            0.0
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536527                              0.0                        0.0
# 536840                              0.0                        0.0
# 536861                              0.0                        0.0
# 536967                              0.0                        0.0
# 536983                              0.0                        0.0
# ...                                 ...                        ...
# C580313                             0.0                        0.0
# C580714                             0.0                        0.0
# C580740                             0.0                        0.0
# C580989                             0.0                        0.0
# C581409                             0.0                        0.0
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536527                      0.0                        0.0
# 536840                      0.0                        0.0
# 536861                      0.0                        0.0
# 536967                      0.0                        0.0
# 536983                      0.0                        0.0
# ...                         ...                        ...
# C580313                     0.0                        0.0
# C580714                     0.0                        0.0
# C580740                     0.0                        0.0
# C580989                     0.0                        0.0
# C581409                     0.0                        0.0
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536527                                     0.0                          0.0
# 536840                                     0.0                          0.0
# 536861                                     0.0                          0.0
# 536967                                     0.0                          0.0
# 536983                                     0.0                          0.0
# ...                                        ...                          ...
# C580313                                    0.0                          0.0
# C580714                                    0.0                          0.0
# C580740                                    0.0                          0.0
# C580989                                    0.0                          0.0
# C581409                                    0.0                          0.0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536527                                  0.0                              0.0
# 536840                                  0.0                              0.0
# 536861                                  0.0                              0.0
# 536967                                  0.0                              0.0
# 536983                                  0.0                              0.0
# ...                                     ...                              ...
# C580313                                 0.0                              0.0
# C580714                                 0.0                              0.0
# C580740                                 0.0                              0.0
# C580989                                 0.0                              0.0
# C581409                                 0.0                              0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                    0.0
# 536840                                    0.0
# 536861                                    0.0
# 536967                                    0.0
# 536983                                    0.0
# ...                                       ...
# C580313                                   0.0
# C580714                                   0.0
# C580740                                   0.0
# C580989                                   0.0
# C581409                                   0.0
#
# [603 rows x 1701 columns]

# %% [markdown]
# ### 2.e. A partir de `df_germany_basket`, altere **TODAS AS COLUNAS** para obedecer a regra booleana abaixo.
# > Regra: Se o valor do atributo for menor ou igual a 0, atribua-o 0. Se o valor do atributo for maior ou igual a 1, atribua-o 1.
#
# Faça a alteração do dataframe reatribuindo a variável `df_germany_basket`.
# > Não use o argumento `inplace=True`
#
# Chame a função `q2.e.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q2.e.hint()`

# %%
# Resposta da 2.e
def func(valor):
  if(valor <= 0):
    return 0
  elif(valor >= 1):
    return 1

#q2.e.hint(1)
#q2.e.hint(2)

df_germany_basket = df_germany_basket.applymap(lambda x: func(x))
df_germany_basket
q2.e.check()
df_germany_basket
# Out:
# CORRETO:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                            0                           0
# 536840                            0                           0
# 536861                            0                           0
# 536967                            0                           0
# 536983                            0                           0
# ...                             ...                         ...
# C580313                           0                           0
# C580714                           0                           0
# C580740                           0                           0
# C580989                           0                           0
# C581409                           0                           0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                      0
# 536840                                      0
# 536861                                      0
# 536967                                      0
# 536983                                      0
# ...                                       ...
# C580313                                     0
# C580714                                     0
# C580740                                     0
# C580989                                     0
# C581409                                     0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                     0                              0
# 536840                                     0                              0
# 536861                                     0                              0
# 536967                                     0                              0
# 536983                                     0                              0
# ...                                      ...                            ...
# C580313                                    0                              0
# C580714                                    0                              0
# C580740                                    0                              0
# C580989                                    0                              0
# C581409                                    0                              0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                         0                            0
# 536840                                         0                            0
# 536861                                         0                            0
# 536967                                         0                            0
# 536983                                         0                            0
# ...                                          ...                          ...
# C580313                                        0                            0
# C580714                                        0                            0
# C580740                                        0                            0
# C580989                                        0                            0
# C581409                                        0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                               0                                   0
# 536840                               0                                   0
# 536861                               0                                   0
# 536967                               0                                   0
# 536983                               0                                   0
# ...                                ...                                 ...
# C580313                              0                                   0
# C580714                              0                                   0
# C580740                              0                                   0
# C580989                              0                                   0
# C581409                              0                                   0
#
# Description  12 PENCILS TALL TUBE SKULLS  ...  YULETIDE IMAGES GIFT WRAP SET  \
# InvoiceNo                                 ...
# 536527                                 0  ...                              0
# 536840                                 0  ...                              0
# 536861                                 0  ...                              0
# 536967                                 0  ...                              0
# 536983                                 0  ...                              0
# ...                                  ...  ...                            ...
# C580313                                0  ...                              0
# C580714                                0  ...                              0
# C580740                                0  ...                              0
# C580989                                0  ...                              0
# C581409                                0  ...                              0
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536527                                0                          0
# 536840                                0                          0
# 536861                                0                          0
# 536967                                0                          0
# 536983                                0                          0
# ...                                 ...                        ...
# C580313                               0                          0
# C580714                               0                          0
# C580740                               0                          0
# C580989                               0                          0
# C581409                               0                          0
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536527                        0                          0
# 536840                        0                          0
# 536861                        0                          0
# 536967                        0                          0
# 536983                        0                          0
# ...                         ...                        ...
# C580313                       0                          0
# C580714                       0                          0
# C580740                       0                          0
# C580989                       0                          0
# C581409                       0                          0
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536527                                       0                            0
# 536840                                       0                            0
# 536861                                       0                            0
# 536967                                       0                            0
# 536983                                       0                            0
# ...                                        ...                          ...
# C580313                                      0                            0
# C580714                                      0                            0
# C580740                                      0                            0
# C580989                                      0                            0
# C581409                                      0                            0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536527                                    0                                0
# 536840                                    0                                0
# 536861                                    0                                0
# 536967                                    0                                0
# 536983                                    0                                0
# ...                                     ...                              ...
# C580313                                   0                                0
# C580714                                   0                                0
# C580740                                   0                                0
# C580989                                   0                                0
# C581409                                   0                                0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                      0
# 536840                                      0
# 536861                                      0
# 536967                                      0
# 536983                                      0
# ...                                       ...
# C580313                                     0
# C580714                                     0
# C580740                                     0
# C580989                                     0
# C581409                                     0
#
# [603 rows x 1701 columns]

# %% [markdown]
# ### 2.f. A partir de `df_germany_basket`, remova a coluna `POSTAGE`.
#
# Faça a alteração do dataframe reatribuindo a variável `df_germany_basket`.
# > Não use o argumento `inplace=True`
#
# Chame a função `q2.f.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q2.f.hint()`

# %%
# Resposta da 2.f

q2.f.hint(2)



df_germany_basket = df_germany_basket.drop('POSTAGE', axis=1)
df_germany_basket

q2.f.check()
df_germany_basket
# Out:
# Dica 2: Você quer dropar uma **coluna**. Então, lembre-se de passar o parâmetro `axis` corretamente.
# CORRETO:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536527                            0                           0
# 536840                            0                           0
# 536861                            0                           0
# 536967                            0                           0
# 536983                            0                           0
# ...                             ...                         ...
# C580313                           0                           0
# C580714                           0                           0
# C580740                           0                           0
# C580989                           0                           0
# C581409                           0                           0
#
# Description  12 IVORY ROSE PEG PLACE SETTINGS  \
# InvoiceNo
# 536527                                      0
# 536840                                      0
# 536861                                      0
# 536967                                      0
# 536983                                      0
# ...                                       ...
# C580313                                     0
# C580714                                     0
# C580740                                     0
# C580989                                     0
# C581409                                     0
#
# Description  12 MESSAGE CARDS WITH ENVELOPES  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536527                                     0                              0
# 536840                                     0                              0
# 536861                                     0                              0
# 536967                                     0                              0
# 536983                                     0                              0
# ...                                      ...                            ...
# C580313                                    0                              0
# C580714                                    0                              0
# C580740                                    0                              0
# C580989                                    0                              0
# C581409                                    0                              0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536527                                         0                            0
# 536840                                         0                            0
# 536861                                         0                            0
# 536967                                         0                            0
# 536983                                         0                            0
# ...                                          ...                          ...
# C580313                                        0                            0
# C580714                                        0                            0
# C580740                                        0                            0
# C580989                                        0                            0
# C581409                                        0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536527                               0                                   0
# 536840                               0                                   0
# 536861                               0                                   0
# 536967                               0                                   0
# 536983                               0                                   0
# ...                                ...                                 ...
# C580313                              0                                   0
# C580714                              0                                   0
# C580740                              0                                   0
# C580989                              0                                   0
# C581409                              0                                   0
#
# Description  12 PENCILS TALL TUBE SKULLS  ...  YULETIDE IMAGES GIFT WRAP SET  \
# InvoiceNo                                 ...
# 536527                                 0  ...                              0
# 536840                                 0  ...                              0
# 536861                                 0  ...                              0
# 536967                                 0  ...                              0
# 536983                                 0  ...                              0
# ...                                  ...  ...                            ...
# C580313                                0  ...                              0
# C580714                                0  ...                              0
# C580740                                0  ...                              0
# C580989                                0  ...                              0
# C581409                                0  ...                              0
#
# Description  ZINC  HEART T-LIGHT HOLDER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536527                                0                          0
# 536840                                0                          0
# 536861                                0                          0
# 536967                                0                          0
# 536983                                0                          0
# ...                                 ...                        ...
# C580313                               0                          0
# C580714                               0                          0
# C580740                               0                          0
# C580989                               0                          0
# C581409                               0                          0
#
# Description  ZINC BOX SIGN HOME  ZINC FOLKART SLEIGH BELLS  \
# InvoiceNo
# 536527                        0                          0
# 536840                        0                          0
# 536861                        0                          0
# 536967                        0                          0
# 536983                        0                          0
# ...                         ...                        ...
# C580313                       0                          0
# C580714                       0                          0
# C580740                       0                          0
# C580989                       0                          0
# C581409                       0                          0
#
# Description  ZINC HEART LATTICE T-LIGHT HOLDER  ZINC METAL HEART DECORATION  \
# InvoiceNo
# 536527                                       0                            0
# 536840                                       0                            0
# 536861                                       0                            0
# 536967                                       0                            0
# 536983                                       0                            0
# ...                                        ...                          ...
# C580313                                      0                            0
# C580714                                      0                            0
# C580740                                      0                            0
# C580989                                      0                            0
# C581409                                      0                            0
#
# Description  ZINC T-LIGHT HOLDER STAR LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# InvoiceNo
# 536527                                    0                                0
# 536840                                    0                                0
# 536861                                    0                                0
# 536967                                    0                                0
# 536983                                    0                                0
# ...                                     ...                              ...
# C580313                                   0                                0
# C580714                                   0                                0
# C580740                                   0                                0
# C580989                                   0                                0
# C581409                                   0                                0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 536527                                      0
# 536840                                      0
# 536861                                      0
# 536967                                      0
# 536983                                      0
# ...                                       ...
# C580313                                     0
# C580714                                     0
# C580740                                     0
# C580989                                     0
# C581409                                     0
#
# [603 rows x 1700 columns]

# %% [markdown]
# ## 3. Faça o cálculo dos itemsets frequentes e regras de associação.
# Utilize o algoritmo _apriori_.

# %% [markdown]
# ### 3.a. A partir de `df_germany_grouped`, calcule os itemsets frequentes utilizando `apriori`.
#
# Utilize o suporte mínimo de 0.07. Utilize o paramêtro `use_colnames=True`.
#
# Armazene-a na variável `germany_frequent_itemsets`.
#
# Chame a função `q3.a.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q3.a.hint()`

# %%
# Resposta da 3.a

q3.a.hint(2)

#apriori(df, min_support=0.6, use_colnames=True)
germany_frequent_itemsets = apriori(df_germany_basket, min_support=0.04, use_colnames=True)

q3.a.check()
# Out:
# Dica 2: Você deve passar os paramêtros na descrição do problema.
# (Para outra dica, chame `.hint(3)`)
# CORRETO:

# %% [markdown]
# ### 3.b. A partir de `germany_frequent_itemsets`, calcule as regras de associação.
#
# Utilize filtro de confiança de `1.0`.
#
# Armazene-a na variável `germany_rules`.
#
# Chame a função `q3.b.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q3.b.hint()`

# %%
# Resposta da 3.b

# q3.b.hint()

germany_rules = association_rules(germany_frequent_itemsets, metric='confidence', min_threshold=0.5)

q3.b.check()
germany_rules
# Out:
# CORRETO:
#                             antecedents                           consequents  \
# 0       (PLASTERS IN TIN CIRCUS PARADE)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 1            (PLASTERS IN TIN SPACEBOY)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 2    (PLASTERS IN TIN WOODLAND ANIMALS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 3         (RED RETROSPOT CHARLOTTE BAG)              (WOODLAND CHARLOTTE BAG)
# 4   (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 5  (ROUND SNACK BOXES SET OF4 WOODLAND)   (ROUND SNACK BOXES SET OF 4 FRUITS)
# 6                  (SPACEBOY LUNCH BOX)  (ROUND SNACK BOXES SET OF4 WOODLAND)
# 7              (WOODLAND CHARLOTTE BAG)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.087894            0.104478  0.051410    0.584906  5.598383
# 1            0.081260            0.104478  0.046434    0.571429  5.469388
# 2            0.104478            0.185738  0.056385    0.539683  2.905612
# 3            0.053068            0.096186  0.044776    0.843750  8.772091
# 4            0.119403            0.185738  0.099502    0.833333  4.486607
# 5            0.185738            0.119403  0.099502    0.535714  4.486607
# 6            0.077944            0.185738  0.053068    0.680851  3.665653
# 7            0.096186            0.185738  0.048093    0.500000  2.691964
#
#    leverage  conviction
# 0  0.042227    2.157395
# 1  0.037945    2.089552
# 2  0.036979    1.768914
# 3  0.039672    5.784411
# 4  0.077325    4.885572
# 5  0.077325    1.896670
# 6  0.038591    2.551354
# 7  0.030228    1.628524

# %% [markdown]
# ## 4. Analise as regras obtidas.

# %% [markdown]
# ### 4.a. A partir de `germany_rules`, recupere as regras com suporte maior ou igual a 0.015 e confiança maior ou igual a 0.75.
#
# Armazene-a na variável `germany_rules_a`.
#
# Chame a função `q4.a.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q4.a.hint()`

# %%
# Resposta da 4.a

# q4.a.hint()

germany_rules_a = germany_rules[germany_rules['confidence'] >= 0.75]

q4.a.check()
germany_rules_a
# Out:
# CORRETO:
#                            antecedents                           consequents  \
# 3        (RED RETROSPOT CHARLOTTE BAG)              (WOODLAND CHARLOTTE BAG)
# 4  (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 3            0.053068            0.096186  0.044776    0.843750  8.772091
# 4            0.119403            0.185738  0.099502    0.833333  4.486607
#
#    leverage  conviction
# 3  0.039672    5.784411
# 4  0.077325    4.885572

# %% [markdown]
# ### 4.b. A partir de `germany_rules`, recupere as regras com lift maior ou igual a 4 e confiança maior ou igual a 0.8.
#
# Armazene-a na variável `germany_rules_b`.
#
# Chame a função `q4.b.check()` no fim da célula para verificar a resposta.
# Você pode pedir dicas com `q4.b.hint()`

# %%
# Resposta da 4.b

q4.b.hint(1)


germany_rules_b = germany_rules[germany_rules['lift'] >= 4]
germany_rules_b = germany_rules[germany_rules['confidence'] >= 0.8]
germany_rules_b
q4.b.check()
germany_rules_b
# Out:
# Dica: Utilize um filtro, como mostrado no roteiro.
# CORRETO:
#                            antecedents                           consequents  \
# 3        (RED RETROSPOT CHARLOTTE BAG)              (WOODLAND CHARLOTTE BAG)
# 4  (ROUND SNACK BOXES SET OF 4 FRUITS)  (ROUND SNACK BOXES SET OF4 WOODLAND)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 3            0.053068            0.096186  0.044776    0.843750  8.772091
# 4            0.119403            0.185738  0.099502    0.833333  4.486607
#
#    leverage  conviction
# 3  0.039672    5.784411
# 4  0.077325    4.885572

# %% [markdown]
# ### 4.c. Quais produtos você recomendaria colocar próximos se fosse organizar um supermercado físico?
#
# Justifique sua resposta com evidências plausíveis em uma resposta completa.
#
# Essa qustão não possui check automático. Mas você pode pedir dica com `q4.c.hint()`.

# %% [markdown]
# **RESPOSTA 4.c.:** Como mostrado pelas regras feitas acima:
# Pelo lift podemos ter como recomendação:
#
#
# *   RED RETROSPOT CHARLOTTE BAG
# *   ROUND SNACK BOXES SET OF4 WOODLAND
# *   ROUND SNACK BOXES SET OF 4 FRUITS
# *   WOODLAND CHARLOTTE BAG

# %% [markdown]
# ## 5. Compare as regras da Alemanha aplicadas agora para a França.
# Essa questão não possui correção automática.

# %%
df_france = df[df['Country'] == 'France']
df_france
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727         ALARM CLOCK BAKELIKE RED        24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                  STARS GIFT TAPE        24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899      CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254     CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138     BAKING SET 9 PIECE RETROSPOT         3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 26     2010-12-01 08:45:00       3.75     12583.0  France
# 27     2010-12-01 08:45:00       3.75     12583.0  France
# 28     2010-12-01 08:45:00       3.75     12583.0  France
# 29     2010-12-01 08:45:00       0.85     12583.0  France
# 30     2010-12-01 08:45:00       0.65     12583.0  France
# ...                    ...        ...         ...     ...
# 541904 2011-12-09 12:50:00       0.85     12680.0  France
# 541905 2011-12-09 12:50:00       2.10     12680.0  France
# 541906 2011-12-09 12:50:00       4.15     12680.0  France
# 541907 2011-12-09 12:50:00       4.15     12680.0  France
# 541908 2011-12-09 12:50:00       4.95     12680.0  France
#
# [8557 rows x 8 columns]

# %%
df_france_grouped = df_france.groupby(by=['InvoiceNo', 'Description'])
df_france_grouped

# %%
df_france_grouped_sum = df_france_grouped['Quantity'].sum()
df_france_grouped_sum
# Out:
# InvoiceNo  Description
# 536370     ALARM CLOCK BAKELIKE GREEN           12
#            ALARM CLOCK BAKELIKE PINK            24
#            ALARM CLOCK BAKELIKE RED             24
#            CHARLOTTE BAG DOLLY GIRL DESIGN      20
#            CIRCUS PARADE LUNCH BOX              24
#                                                 ..
# C580263    SET OF 6 HALLOWEEN GHOST T-LIGHTS   -36
#            SKULL SHOULDER BAG                  -10
# C581316    GLASS  SONGBIRD STORAGE JAR          -1
#            RED RETROSPOT SUGAR JAM BOWL         -1
#            REGENCY SUGAR BOWL GREEN             -1
# Name: Quantity, Length: 8519, dtype: int64

# %%
df_france_basket = df_france_grouped_sum.unstack()
df_france_basket = df_france_basket.reset_index()
df_france_basket = df_france_basket.fillna(0)
df_france_basket = df_france_basket.set_index('InvoiceNo')
df_france_basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# C579532                         0.0                         0.0
# C579562                         0.0                         0.0
# C580161                         0.0                         0.0
# C580263                         0.0                         0.0
# C581316                         0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
# ...                                ...                              ...
# C579532                            0.0                              0.0
# C579562                            0.0                              0.0
# C580161                            0.0                              0.0
# C580263                            0.0                              0.0
# C581316                            0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# 536852                                 0.0
# 536974                                 0.0
# 537065                                 0.0
# 537463                                 0.0
# ...                                    ...
# C579532                                0.0
# C579562                                0.0
# C580161                                0.0
# C580263                                0.0
# C581316                                0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                       0.0                          0.0
# 536852                                       0.0                          0.0
# 536974                                       0.0                          0.0
# 537065                                       0.0                          0.0
# 537463                                       0.0                          0.0
# ...                                          ...                          ...
# C579532                                      0.0                          0.0
# C579562                                      0.0                          0.0
# C580161                                      0.0                          0.0
# C580263                                      0.0                          0.0
# C581316                                      0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                             0.0                                 0.0
# 536852                             0.0                                 0.0
# 536974                             0.0                                 0.0
# 537065                             0.0                                 0.0
# 537463                             0.0                                 0.0
# ...                                ...                                 ...
# C579532                            0.0                                 0.0
# C579562                            0.0                                 0.0
# C580161                            0.0                                 0.0
# C580263                            0.0                                 0.0
# C581316                            0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                 0.0  ...                          0.0
# 536852                                 0.0  ...                          0.0
# 536974                                 0.0  ...                          0.0
# 537065                                 0.0  ...                          0.0
# 537463                                 0.0  ...                          0.0
# ...                                    ...  ...                          ...
# C579532                                0.0  ...                          0.0
# C579562                                0.0  ...                          0.0
# C580161                                0.0  ...                          0.0
# C580263                                0.0  ...                          0.0
# C581316                                0.0  ...                          0.0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
# ...                                     ...                              ...
# C579532                                 0.0                              0.0
# C579562                                 0.0                              0.0
# C580161                                 0.0                              0.0
# C580263                                 0.0                              0.0
# C581316                                 0.0                              0.0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                           0.0                        0.0
# 536852                           0.0                        0.0
# 536974                           0.0                        0.0
# 537065                           0.0                        0.0
# 537463                           0.0                        0.0
# ...                              ...                        ...
# C579532                          0.0                        0.0
# C579562                          0.0                        0.0
# C580161                          0.0                        0.0
# C580263                          0.0                        0.0
# C581316                          0.0                        0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                             0.0                         0.0
# 536852                             0.0                         0.0
# 536974                             0.0                         0.0
# 537065                             0.0                         0.0
# 537463                             0.0                         0.0
# ...                                ...                         ...
# C579532                            0.0                         0.0
# C579562                            0.0                         0.0
# C580161                            0.0                         0.0
# C580263                            0.0                         0.0
# C581316                            0.0                         0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                               0.0                             0.0
# 536852                               0.0                             0.0
# 536974                               0.0                             0.0
# 537065                               0.0                             0.0
# 537463                               0.0                             0.0
# ...                                  ...                             ...
# C579532                              0.0                             0.0
# C579562                              0.0                             0.0
# C580161                              0.0                             0.0
# C580263                              0.0                             0.0
# C581316                              0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                   0.0
# 536852                                   0.0
# 536974                                   0.0
# 537065                                   0.0
# 537463                                   0.0
# ...                                      ...
# C579532                                  0.0
# C579562                                  0.0
# C580161                                  0.0
# C580263                                  0.0
# C581316                                  0.0
#
# [461 rows x 1564 columns]

# %%
def func(valor):
  if(valor <= 0):
    return 0
  elif(valor >= 1):
    return 1

df_france_basket = df_france_basket.applymap(lambda x: func(x))
df_france_basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
# ...                             ...                         ...
# C579532                           0                           0
# C579562                           0                           0
# C580161                           0                           0
# C580263                           0                           0
# C581316                           0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
# ...                                ...                              ...
# C579532                              0                                0
# C579562                              0                                0
# C580161                              0                                0
# C580263                              0                                0
# C581316                              0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                   0
# 536852                                   0
# 536974                                   0
# 537065                                   0
# 537463                                   0
# ...                                    ...
# C579532                                  0
# C579562                                  0
# C580161                                  0
# C580263                                  0
# C581316                                  0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                         0                            0
# 536852                                         0                            0
# 536974                                         0                            0
# 537065                                         0                            0
# 537463                                         0                            0
# ...                                          ...                          ...
# C579532                                        0                            0
# C579562                                        0                            0
# C580161                                        0                            0
# C580263                                        0                            0
# C581316                                        0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                               0                                   0
# 536852                               0                                   0
# 536974                               0                                   0
# 537065                               0                                   0
# 537463                               0                                   0
# ...                                ...                                 ...
# C579532                              0                                   0
# C579562                              0                                   0
# C580161                              0                                   0
# C580263                              0                                   0
# C581316                              0                                   0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                   0  ...                            0
# 536852                                   0  ...                            0
# 536974                                   0  ...                            0
# 537065                                   0  ...                            0
# 537463                                   0  ...                            0
# ...                                    ...  ...                          ...
# C579532                                  0  ...                            0
# C579562                                  0  ...                            0
# C580161                                  0  ...                            0
# C580263                                  0  ...                            0
# C581316                                  0  ...                            0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                    0                                0
# 536852                                    0                                0
# 536974                                    0                                0
# 537065                                    0                                0
# 537463                                    0                                0
# ...                                     ...                              ...
# C579532                                   0                                0
# C579562                                   0                                0
# C580161                                   0                                0
# C580263                                   0                                0
# C581316                                   0                                0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                             0                          0
# 536852                             0                          0
# 536974                             0                          0
# 537065                             0                          0
# 537463                             0                          0
# ...                              ...                        ...
# C579532                            0                          0
# C579562                            0                          0
# C580161                            0                          0
# C580263                            0                          0
# C581316                            0                          0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                               0                           0
# 536852                               0                           0
# 536974                               0                           0
# 537065                               0                           0
# 537463                               0                           0
# ...                                ...                         ...
# C579532                              0                           0
# C579562                              0                           0
# C580161                              0                           0
# C580263                              0                           0
# C581316                              0                           0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                                 0                               0
# 536852                                 0                               0
# 536974                                 0                               0
# 537065                                 0                               0
# 537463                                 0                               0
# ...                                  ...                             ...
# C579532                                0                               0
# C579562                                0                               0
# C580161                                0                               0
# C580263                                0                               0
# C581316                                0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                     0
# 536852                                     0
# 536974                                     0
# 537065                                     0
# 537463                                     0
# ...                                      ...
# C579532                                    0
# C579562                                    0
# C580161                                    0
# C580263                                    0
# C581316                                    0
#
# [461 rows x 1564 columns]

# %%
df_france_basket = df_france_basket.drop('POSTAGE', axis=1)
df_france_basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
# ...                             ...                         ...
# C579532                           0                           0
# C579562                           0                           0
# C580161                           0                           0
# C580263                           0                           0
# C581316                           0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
# ...                                ...                              ...
# C579532                              0                                0
# C579562                              0                                0
# C580161                              0                                0
# C580263                              0                                0
# C581316                              0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                   0
# 536852                                   0
# 536974                                   0
# 537065                                   0
# 537463                                   0
# ...                                    ...
# C579532                                  0
# C579562                                  0
# C580161                                  0
# C580263                                  0
# C581316                                  0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                         0                            0
# 536852                                         0                            0
# 536974                                         0                            0
# 537065                                         0                            0
# 537463                                         0                            0
# ...                                          ...                          ...
# C579532                                        0                            0
# C579562                                        0                            0
# C580161                                        0                            0
# C580263                                        0                            0
# C581316                                        0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                               0                                   0
# 536852                               0                                   0
# 536974                               0                                   0
# 537065                               0                                   0
# 537463                               0                                   0
# ...                                ...                                 ...
# C579532                              0                                   0
# C579562                              0                                   0
# C580161                              0                                   0
# C580263                              0                                   0
# C581316                              0                                   0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                   0  ...                            0
# 536852                                   0  ...                            0
# 536974                                   0  ...                            0
# 537065                                   0  ...                            0
# 537463                                   0  ...                            0
# ...                                    ...  ...                          ...
# C579532                                  0  ...                            0
# C579562                                  0  ...                            0
# C580161                                  0  ...                            0
# C580263                                  0  ...                            0
# C581316                                  0  ...                            0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                    0                                0
# 536852                                    0                                0
# 536974                                    0                                0
# 537065                                    0                                0
# 537463                                    0                                0
# ...                                     ...                              ...
# C579532                                   0                                0
# C579562                                   0                                0
# C580161                                   0                                0
# C580263                                   0                                0
# C581316                                   0                                0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                             0                          0
# 536852                             0                          0
# 536974                             0                          0
# 537065                             0                          0
# 537463                             0                          0
# ...                              ...                        ...
# C579532                            0                          0
# C579562                            0                          0
# C580161                            0                          0
# C580263                            0                          0
# C581316                            0                          0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                               0                           0
# 536852                               0                           0
# 536974                               0                           0
# 537065                               0                           0
# 537463                               0                           0
# ...                                ...                         ...
# C579532                              0                           0
# C579562                              0                           0
# C580161                              0                           0
# C580263                              0                           0
# C581316                              0                           0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                                 0                               0
# 536852                                 0                               0
# 536974                                 0                               0
# 537065                                 0                               0
# 537463                                 0                               0
# ...                                  ...                             ...
# C579532                                0                               0
# C579562                                0                               0
# C580161                                0                               0
# C580263                                0                               0
# C581316                                0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                     0
# 536852                                     0
# 536974                                     0
# 537065                                     0
# 537463                                     0
# ...                                      ...
# C579532                                    0
# C579562                                    0
# C580161                                    0
# C580263                                    0
# C581316                                    0
#
# [461 rows x 1563 columns]

# %%
france_frequent_itemsets = apriori(df_france_basket, min_support=0.04, use_colnames=True)
france_frequent_itemsets
# Out:
#       support                                           itemsets
# 0    0.060738                      (4 TRADITIONAL SPINNING TOPS)
# 1    0.082430                       (ALARM CLOCK BAKELIKE GREEN)
# 2    0.086768                        (ALARM CLOCK BAKELIKE PINK)
# 3    0.080260                         (ALARM CLOCK BAKELIKE RED)
# 4    0.058568                       (ASSORTED COLOUR MINI CASES)
# ..        ...                                                ...
# 122  0.086768  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 123  0.104121  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 124  0.054230  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 125  0.058568  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN CIR...
# 126  0.084599  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
#
# [127 rows x 2 columns]

# %%
france_rules = association_rules(france_frequent_itemsets, metric='confidence', min_threshold=0.5)
france_rules
# Out:
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                         (ALARM CLOCK BAKELIKE PINK)
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 4                        (ALARM CLOCK BAKELIKE GREEN)
# 5                          (ALARM CLOCK BAKELIKE RED)
# 6                         (ALARM CLOCK BAKELIKE PINK)
# 7                          (ALARM CLOCK BAKELIKE RED)
# 8                      (CHILDRENS CUTLERY DOLLY GIRL)
# 9                        (CHILDRENS CUTLERY SPACEBOY)
# 10                             (DOLLY GIRL LUNCH BOX)
# 11                               (SPACEBOY LUNCH BOX)
# 12                           (LUNCH BAG APPLE DESIGN)
# 13                        (LUNCH BAG SPACEBOY DESIGN)
# 14                           (LUNCH BAG APPLE DESIGN)
# 15                      (LUNCH BAG DOLLY GIRL DESIGN)
# 16                        (LUNCH BAG SPACEBOY DESIGN)
# 17                               (LUNCH BAG WOODLAND)
# 18                        (LUNCH BAG SPACEBOY DESIGN)
# 19                (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 20                     (PACK OF 6 SKULL PAPER PLATES)
# 21                       (PACK OF 6 SKULL PAPER CUPS)
# 22                         (PLASTERS IN TIN SPACEBOY)
# 23                    (PLASTERS IN TIN CIRCUS PARADE)
# 24                        (PLASTERS IN TIN STRONGMAN)
# 25                    (PLASTERS IN TIN CIRCUS PARADE)
# 26                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 27                         (PLASTERS IN TIN SPACEBOY)
# 28                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 29                        (PLASTERS IN TIN STRONGMAN)
# 30                (ROUND SNACK BOXES SET OF 4 FRUITS)
# 31                      (SET/6 RED SPOTTY PAPER CUPS)
# 32               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 33                    (SET/6 RED SPOTTY PAPER PLATES)
# 34               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 35                    (SET/6 RED SPOTTY PAPER PLATES)
# 36                      (SET/6 RED SPOTTY PAPER CUPS)
# 37  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 38  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 39  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...
# 40                       (ALARM CLOCK BAKELIKE GREEN)
# 41                         (ALARM CLOCK BAKELIKE RED)
# 42                        (ALARM CLOCK BAKELIKE PINK)
# 43  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN CIR...
# 44  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN WOO...
# 45  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 46                         (PLASTERS IN TIN SPACEBOY)
# 47  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 48  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 49  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 50                    (SET/6 RED SPOTTY PAPER PLATES)
# 51                      (SET/6 RED SPOTTY PAPER CUPS)
# 52               (SET/20 RED RETROSPOT PAPER NAPKINS)
#
#                                           consequents  antecedent support  \
# 0                         (ALARM CLOCK BAKELIKE PINK)            0.082430
# 1                        (ALARM CLOCK BAKELIKE GREEN)            0.086768
# 2                          (ALARM CLOCK BAKELIKE RED)            0.082430
# 3                        (ALARM CLOCK BAKELIKE GREEN)            0.080260
# 4                (ROUND SNACK BOXES SET OF4 WOODLAND)            0.082430
# 5                         (ALARM CLOCK BAKELIKE PINK)            0.080260
# 6                          (ALARM CLOCK BAKELIKE RED)            0.086768
# 7                (ROUND SNACK BOXES SET OF4 WOODLAND)            0.080260
# 8                        (CHILDRENS CUTLERY SPACEBOY)            0.060738
# 9                      (CHILDRENS CUTLERY DOLLY GIRL)            0.058568
# 10                               (SPACEBOY LUNCH BOX)            0.084599
# 11                             (DOLLY GIRL LUNCH BOX)            0.106291
# 12                          (LUNCH BAG RED RETROSPOT)            0.106291
# 13                           (LUNCH BAG APPLE DESIGN)            0.101952
# 14                        (LUNCH BAG SPACEBOY DESIGN)            0.106291
# 15                        (LUNCH BAG SPACEBOY DESIGN)            0.071584
# 16                          (LUNCH BAG RED RETROSPOT)            0.101952
# 17                        (LUNCH BAG SPACEBOY DESIGN)            0.099783
# 18                               (LUNCH BAG WOODLAND)            0.101952
# 19                 (LUNCH BOX WITH CUTLERY RETROSPOT)            0.104121
# 20                       (PACK OF 6 SKULL PAPER CUPS)            0.047722
# 21                     (PACK OF 6 SKULL PAPER PLATES)            0.054230
# 22                    (PLASTERS IN TIN CIRCUS PARADE)            0.117137
# 23                         (PLASTERS IN TIN SPACEBOY)            0.143167
# 24                    (PLASTERS IN TIN CIRCUS PARADE)            0.069414
# 25                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.143167
# 26                    (PLASTERS IN TIN CIRCUS PARADE)            0.145336
# 27                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.117137
# 28                         (PLASTERS IN TIN SPACEBOY)            0.145336
# 29                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.069414
# 30               (ROUND SNACK BOXES SET OF4 WOODLAND)            0.091106
# 31               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.117137
# 32                      (SET/6 RED SPOTTY PAPER CUPS)            0.112798
# 33               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.108460
# 34                    (SET/6 RED SPOTTY PAPER PLATES)            0.112798
# 35                      (SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 36                    (SET/6 RED SPOTTY PAPER PLATES)            0.117137
# 37                        (ALARM CLOCK BAKELIKE PINK)            0.067245
# 38                         (ALARM CLOCK BAKELIKE RED)            0.062907
# 39                       (ALARM CLOCK BAKELIKE GREEN)            0.062907
# 40  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...            0.082430
# 41  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...            0.080260
# 42  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...            0.086768
# 43                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.075922
# 44                    (PLASTERS IN TIN CIRCUS PARADE)            0.088937
# 45                         (PLASTERS IN TIN SPACEBOY)            0.086768
# 46  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...            0.117137
# 47               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.104121
# 48                      (SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 49                    (SET/6 RED SPOTTY PAPER PLATES)            0.086768
# 50  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...            0.108460
# 51  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...            0.117137
# 52  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...            0.112798
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.086768  0.062907    0.763158   8.795395  0.055754    3.855869
# 1             0.082430  0.062907    0.725000   8.795395  0.055754    3.336620
# 2             0.080260  0.067245    0.815789  10.164296  0.060629    4.992873
# 3             0.082430  0.067245    0.837838  10.164296  0.060629    5.658351
# 4             0.134490  0.041215    0.500000   3.717742  0.030129    1.731020
# 5             0.086768  0.062907    0.783784   9.033108  0.055943    4.223698
# 6             0.080260  0.062907    0.725000   9.033108  0.055943    3.344508
# 7             0.134490  0.043384    0.540541   4.019180  0.032590    1.883757
# 8             0.058568  0.054230    0.892857  15.244709  0.050673    8.786696
# 9             0.060738  0.054230    0.925926  15.244709  0.050673   12.680043
# 10            0.106291  0.060738    0.717949   6.754579  0.051745    3.168606
# 11            0.084599  0.060738    0.571429   6.754579  0.051745    2.135936
# 12            0.130152  0.056399    0.530612   4.076871  0.042565    1.853155
# 13            0.106291  0.054230    0.531915   5.004342  0.043393    1.909288
# 14            0.101952  0.054230    0.510204   5.004342  0.043393    1.833514
# 15            0.101952  0.043384    0.606061   5.944552  0.036086    2.279660
# 16            0.130152  0.056399    0.553191   4.250355  0.043130    1.946803
# 17            0.101952  0.054230    0.543478   5.330712  0.044057    1.967152
# 18            0.099783  0.054230    0.531915   5.330712  0.044057    1.923191
# 19            0.121475  0.054230    0.520833   4.287574  0.041582    1.833443
# 20            0.054230  0.043384    0.909091  16.763636  0.040796   10.403471
# 21            0.047722  0.043384    0.800000  16.763636  0.040796    4.761388
# 22            0.143167  0.075922    0.648148   4.527217  0.059152    2.435209
# 23            0.117137  0.075922    0.530303   4.527217  0.059152    1.879645
# 24            0.143167  0.049892    0.718750   5.020360  0.039954    3.046517
# 25            0.145336  0.086768    0.606061   4.170059  0.065961    2.169531
# 26            0.143167  0.086768    0.597015   4.170059  0.065961    2.126215
# 27            0.145336  0.088937    0.759259   5.224157  0.071913    3.550142
# 28            0.117137  0.088937    0.611940   5.224157  0.071913    2.275071
# 29            0.145336  0.041215    0.593750   4.085354  0.031126    2.103788
# 30            0.134490  0.054230    0.595238   4.425883  0.041977    2.138318
# 31            0.112798  0.086768    0.740741   6.566952  0.073555    3.422064
# 32            0.117137  0.086768    0.769231   6.566952  0.073555    3.825741
# 33            0.112798  0.086768    0.800000   7.092308  0.074534    4.436009
# 34            0.108460  0.086768    0.769231   7.092308  0.074534    3.863341
# 35            0.117137  0.104121    0.960000   8.195556  0.091417   22.071584
# 36            0.108460  0.104121    0.888889   8.195556  0.091417    8.023861
# 37            0.086768  0.054230    0.806452   9.294355  0.048395    4.718366
# 38            0.080260  0.054230    0.862069  10.740913  0.049181    6.668113
# 39            0.082430  0.054230    0.862069  10.458258  0.049045    6.652386
# 40            0.062907  0.054230    0.657895  10.458258  0.049045    2.739196
# 41            0.062907  0.054230    0.675676  10.740913  0.049181    2.889371
# 42            0.067245  0.054230    0.625000   9.294355  0.048395    2.487346
# 43            0.145336  0.058568    0.771429   5.307889  0.047534    3.739154
# 44            0.143167  0.058568    0.658537   4.599778  0.045835    2.509297
# 45            0.117137  0.058568    0.675000   5.762500  0.048405    2.716503
# 46            0.086768  0.058568    0.500000   5.762500  0.048405    1.826464
# 47            0.112798  0.084599    0.812500   7.203125  0.072854    4.731743
# 48            0.117137  0.084599    0.975000   8.323611  0.074435   35.314534
# 49            0.108460  0.084599    0.975000   8.989500  0.075188   35.661605
# 50            0.086768  0.084599    0.780000   8.989500  0.075188    4.151055
# 51            0.086768  0.084599    0.722222   8.323611  0.074435    3.287636
# 52            0.104121  0.084599    0.750000   7.203125  0.072854    3.583514

# %%
france_rules_a = france_rules[france_rules['confidence'] >= 0.75]
france_rules_a
# Out:
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 5                          (ALARM CLOCK BAKELIKE RED)
# 8                      (CHILDRENS CUTLERY DOLLY GIRL)
# 9                        (CHILDRENS CUTLERY SPACEBOY)
# 20                     (PACK OF 6 SKULL PAPER PLATES)
# 21                       (PACK OF 6 SKULL PAPER CUPS)
# 27                         (PLASTERS IN TIN SPACEBOY)
# 32               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 33                    (SET/6 RED SPOTTY PAPER PLATES)
# 34               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 35                    (SET/6 RED SPOTTY PAPER PLATES)
# 36                      (SET/6 RED SPOTTY PAPER CUPS)
# 37  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 38  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 39  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...
# 43  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN CIR...
# 47  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 48  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 49  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
# 50                    (SET/6 RED SPOTTY PAPER PLATES)
# 52               (SET/20 RED RETROSPOT PAPER NAPKINS)
#
#                                           consequents  antecedent support  \
# 0                         (ALARM CLOCK BAKELIKE PINK)            0.082430
# 2                          (ALARM CLOCK BAKELIKE RED)            0.082430
# 3                        (ALARM CLOCK BAKELIKE GREEN)            0.080260
# 5                         (ALARM CLOCK BAKELIKE PINK)            0.080260
# 8                        (CHILDRENS CUTLERY SPACEBOY)            0.060738
# 9                      (CHILDRENS CUTLERY DOLLY GIRL)            0.058568
# 20                       (PACK OF 6 SKULL PAPER CUPS)            0.047722
# 21                     (PACK OF 6 SKULL PAPER PLATES)            0.054230
# 27                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.117137
# 32                      (SET/6 RED SPOTTY PAPER CUPS)            0.112798
# 33               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.108460
# 34                    (SET/6 RED SPOTTY PAPER PLATES)            0.112798
# 35                      (SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 36                    (SET/6 RED SPOTTY PAPER PLATES)            0.117137
# 37                        (ALARM CLOCK BAKELIKE PINK)            0.067245
# 38                         (ALARM CLOCK BAKELIKE RED)            0.062907
# 39                       (ALARM CLOCK BAKELIKE GREEN)            0.062907
# 43                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.075922
# 47               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.104121
# 48                      (SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 49                    (SET/6 RED SPOTTY PAPER PLATES)            0.086768
# 50  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...            0.108460
# 52  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...            0.112798
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.086768  0.062907    0.763158   8.795395  0.055754    3.855869
# 2             0.080260  0.067245    0.815789  10.164296  0.060629    4.992873
# 3             0.082430  0.067245    0.837838  10.164296  0.060629    5.658351
# 5             0.086768  0.062907    0.783784   9.033108  0.055943    4.223698
# 8             0.058568  0.054230    0.892857  15.244709  0.050673    8.786696
# 9             0.060738  0.054230    0.925926  15.244709  0.050673   12.680043
# 20            0.054230  0.043384    0.909091  16.763636  0.040796   10.403471
# 21            0.047722  0.043384    0.800000  16.763636  0.040796    4.761388
# 27            0.145336  0.088937    0.759259   5.224157  0.071913    3.550142
# 32            0.117137  0.086768    0.769231   6.566952  0.073555    3.825741
# 33            0.112798  0.086768    0.800000   7.092308  0.074534    4.436009
# 34            0.108460  0.086768    0.769231   7.092308  0.074534    3.863341
# 35            0.117137  0.104121    0.960000   8.195556  0.091417   22.071584
# 36            0.108460  0.104121    0.888889   8.195556  0.091417    8.023861
# 37            0.086768  0.054230    0.806452   9.294355  0.048395    4.718366
# 38            0.080260  0.054230    0.862069  10.740913  0.049181    6.668113
# 39            0.082430  0.054230    0.862069  10.458258  0.049045    6.652386
# 43            0.145336  0.058568    0.771429   5.307889  0.047534    3.739154
# 47            0.112798  0.084599    0.812500   7.203125  0.072854    4.731743
# 48            0.117137  0.084599    0.975000   8.323611  0.074435   35.314534
# 49            0.108460  0.084599    0.975000   8.989500  0.075188   35.661605
# 50            0.086768  0.084599    0.780000   8.989500  0.075188    4.151055
# 52            0.104121  0.084599    0.750000   7.203125  0.072854    3.583514

# %%
france_rules_b = france_rules[france_rules['lift'] >= 4]
france_rules_b = france_rules[france_rules['confidence'] >= 0.8]
france_rules_b
# Out:
#                                           antecedents  \
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 8                      (CHILDRENS CUTLERY DOLLY GIRL)
# 9                        (CHILDRENS CUTLERY SPACEBOY)
# 20                     (PACK OF 6 SKULL PAPER PLATES)
# 35                    (SET/6 RED SPOTTY PAPER PLATES)
# 36                      (SET/6 RED SPOTTY PAPER CUPS)
# 37  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 38  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 39  (ALARM CLOCK BAKELIKE RED, ALARM CLOCK BAKELIK...
# 47  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 48  (SET/6 RED SPOTTY PAPER PLATES, SET/20 RED RET...
# 49  (SET/6 RED SPOTTY PAPER CUPS, SET/20 RED RETRO...
#
#                              consequents  antecedent support  \
# 2             (ALARM CLOCK BAKELIKE RED)            0.082430
# 3           (ALARM CLOCK BAKELIKE GREEN)            0.080260
# 8           (CHILDRENS CUTLERY SPACEBOY)            0.060738
# 9         (CHILDRENS CUTLERY DOLLY GIRL)            0.058568
# 20          (PACK OF 6 SKULL PAPER CUPS)            0.047722
# 35         (SET/6 RED SPOTTY PAPER CUPS)            0.108460
# 36       (SET/6 RED SPOTTY PAPER PLATES)            0.117137
# 37           (ALARM CLOCK BAKELIKE PINK)            0.067245
# 38            (ALARM CLOCK BAKELIKE RED)            0.062907
# 39          (ALARM CLOCK BAKELIKE GREEN)            0.062907
# 47  (SET/20 RED RETROSPOT PAPER NAPKINS)            0.104121
# 48         (SET/6 RED SPOTTY PAPER CUPS)            0.086768
# 49       (SET/6 RED SPOTTY PAPER PLATES)            0.086768
#
#     consequent support   support  confidence       lift  leverage  conviction
# 2             0.080260  0.067245    0.815789  10.164296  0.060629    4.992873
# 3             0.082430  0.067245    0.837838  10.164296  0.060629    5.658351
# 8             0.058568  0.054230    0.892857  15.244709  0.050673    8.786696
# 9             0.060738  0.054230    0.925926  15.244709  0.050673   12.680043
# 20            0.054230  0.043384    0.909091  16.763636  0.040796   10.403471
# 35            0.117137  0.104121    0.960000   8.195556  0.091417   22.071584
# 36            0.108460  0.104121    0.888889   8.195556  0.091417    8.023861
# 37            0.086768  0.054230    0.806452   9.294355  0.048395    4.718366
# 38            0.080260  0.054230    0.862069  10.740913  0.049181    6.668113
# 39            0.082430  0.054230    0.862069  10.458258  0.049045    6.652386
# 47            0.112798  0.084599    0.812500   7.203125  0.072854    4.731743
# 48            0.117137  0.084599    0.975000   8.323611  0.074435   35.314534
# 49            0.108460  0.084599    0.975000   8.989500  0.075188   35.661605

# %% [markdown]
# ### 5.a. Existe alguma similaridade nas principais regras?

# %% [markdown]
# **RESPOSTA 5.a.:** {{ESCREVA AQUI}}

# %% [markdown]
# ### 5.b. Quais produtos você recomendaria colocar próximos em um supermercado físico na França?

# %% [markdown]
# **RESPOSTA 5.b.:** Recomendaria colocar próximo em um supermercado:
#
#
# *   ALARM CLOCK BAKELIKE RED
# *   ALARM CLOCK BAKELIKE GREEN
# *   CHILDRENS CUTLERY SPACEBOY
# *   CHILDRENS CUTLERY DOLLY GIRL

# %% [markdown]
# ### 5.c. Liste 5 cenários hipotéticos que você vê utilidade de se analisar regras de associação

# %% [markdown]
# **RESPOSTA 5.c.:**
#
#
# 1.   Pode ser usada para descobrir padrões de compras
# 2.   Pode ser usada em um site de streaming, para sugerir filmes para pessoas que assistem um determinado gênero
# 3.   Pode ser usado para fazer propagandas após uma compra em algum site.
# 4.   Pode ser usado para oferecer cupons em determinados ambientes
# 5.  Pode ser usada para sequência de eventos climáticos

# %% [markdown]
# ### 5.d. Utilize a função auxiliar abaixo para calcular conjuntos de itens frequentes (utilize suporte mínimo no intervalo [0.05, 0.3]) variando os tamanhos. Qual padrão você observa?
# Qual variável você acredita que afeta a performance desse método? Experimente e discorra sobre quando usar esse método.

# %%
# Gera uma matriz 2D de strings aleatórias.
#
# Parâmetro dv (different values): Quantidade de strings aleatórias únicas que a matriz irá conter.
# Parâmetro vpi (values per instance): Quantidade de strings aleatórias que cada instância terá.
# Parâmetro n: Quantidade de instâncias que será retornada.
def generate_fictional_data(dv=50, vpi=10, n=2500000):
    instances = [''.join(random.choices(string.ascii_uppercase + string.digits, k=20)) for _i in range(dv)]
    fictional_data = [random.choices(instances, k=vpi) for _i in range(n)]
    return fictional_data

# %% [markdown]
# **RESPOSTA 5.d.:** {{ESCREVA AQUI}}

# %%
# RESPOSTA 5.d
